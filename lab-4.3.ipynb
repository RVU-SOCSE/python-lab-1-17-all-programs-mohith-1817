# %%
file1=open("C:\\Users\\RVUW229\\Desktop\\67\\lolll.txt","x")

# %%
file1.write("siuuu")
# Out:
# 5

# %%
file1.close()

# %%
file1=open("C:\\Users\\RVUW229\\Desktop\\67\\lolll.txt","r")
res=file1.read()
print(res)
# Out:
# siuuu

# %%
file1 = open("C:\\Users\\RVUW229\\Desktop\\67\\lolll.txt","a")
file1.write("cristiaaanoooooooo")
file1.close()

# %%
with open("C:\\Users\\RVUW229\\Desktop\\67\\lolll.txt", "r+") as file1:
    print("\nReading using r+ mode:")
    print(file1.read())
# Out:
# Reading using r+ mode:
# siuuucristiaaanoooooooo
# This line is added using r+ mode/n cristiaaanoooooooo /n
# This line is added using r+ modecristiaaanoooooooo
# This line is added using r+ mode
#  This line is added using r+ mode
# This line is added using r+ mode
# This line is added using r+ mode
# This line is added using r+ mode
