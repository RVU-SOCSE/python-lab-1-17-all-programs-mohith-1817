# %%
#Handling Division by Zero using Try-Except
try:
    a=10
    b=0
    print(a/b)
except:
    print("error occured!")
# Out:
# error occured!

# %%
#Handling Invalid Input Using Try-Except
try:
    num=int(input("enter a number:"))
    print(num)
except ValueError:
    print("invalid input!please enter the number.")
# Out:
# enter a number: a
# invalid input!please enter the number.

# %%
#MULTUPLE EXCEPR BLOCKS
try:
    a=int(input("enter the number:"))
    b=int(input("enter the number:"))
    print(a/b)
except ValueError:
    print("invalid number entered.")
except ZeroDivisionError:
    print("cannot divide by zero.")
# Out:
# enter the number: 10
# enter the number: 0
# cannot divide by zero.

# %%
#Using else block
try:
    a=int(input("Enter number"))
    b=int(input("Enter number"))
    result=a/b
except zerodivisionerror:
    print("division by zero is not allowed")
else:
    print("result=",result)
# Out:
# Enter number 10
# Enter number 4
# result= 2.5

# %%
#Using finally block
try:
    f = open("data.txt","r")
    print(f.read())
except FileNotFoundError:
    print("print not found")

finally:
    print("Execution completed")
# Out:
# print not found
# Execution completed

# %%
#Handling multiple exception in one line
try:
    num=int("abc")
except(ValueError,TypeError):
    print("Error occured while converting the value.")
# Out:
# Error occured while converting the value.

# %%
# Raising an exception
try:
   age = -5
   if age < 0:
   raise ValueError("Age cannot be negative.")
excepr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 5
#       2 age = -5
#       4 if age < 0:
# ----> 5     raise ValueError("Age cannot be negative.")
#
# ValueError: Age cannot be negative.

# %%
#User defined exception
class MyError(Exception):
    pass

try:
    raise MyError("custom error occurred!")
except MyError as e:
    print(e)
# Out:
# custom error occurred!

# %%
#Exception Handling for File Reading
try:
    file = open("sampke.txt","r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("file not found")
# Out:
# file not found

# %%
#CAtching exception object
try:
    x=5/0
except Exception as e:
    print("Error message:",e)
# Out:
# Error message: division by zero

# %%
import pandas as pd
